# %%
import pandas as pd

# %%
calendar_df = pd.read_csv('/home/csl/otp/two_taipei_gtfs/calendar.txt')

calendar_df
# Out:
#                service_id  monday  tuesday  wednesday  thursday  friday  \
# 0       TPE101320_0_F_1_1       0        0          0         0       0
# 1       TPE101320_0_F_2_1       1        0          0         0       0
# 2       TPE101320_0_F_3_1       1        0          0         0       0
# 3       TPE101320_0_F_4_1       1        0          0         0       0
# 4       TPE101320_0_F_5_1       1        0          0         0       0
# ...                   ...     ...      ...        ...       ...     ...
# 137805         AFR_53_0_8       1        1          1         1       1
# 137806         AFR_54_1_9       1        1          1         1       1
# 137807         AFR_6_1_10       0        0          0         0       0
# 137808        AFR_97_0_11       1        1          1         1       1
# 137809        AFR_98_1_12       1        1          1         1       1
#
#         saturday  sunday  start_date  end_date
# 0              0       1    20240423  20240523
# 1              0       0    20240423  20240523
# 2              0       0    20240423  20240523
# 3              0       0    20240423  20240523
# 4              0       0    20240423  20240523
# ...          ...     ...         ...       ...
# 137805         1       1    20240423  20240523
# 137806         1       1    20240423  20240523
# 137807         1       1    20240423  20240523
# 137808         1       1    20240423  20240523
# 137809         1       1    20240423  20240523
#
# [137810 rows x 10 columns]

# %%
# Out:
#                service_id  monday  tuesday  wednesday  thursday  friday  \
# 0       TPE101320_0_F_1_1       0        0          0         0       0
# 1       TPE101320_0_F_2_1       1        0          0         0       0
# 2       TPE101320_0_F_3_1       1        0          0         0       0
# 3       TPE101320_0_F_4_1       1        0          0         0       0
# 4       TPE101320_0_F_5_1       1        0          0         0       0
# ...                   ...     ...      ...        ...       ...     ...
# 137805         AFR_53_0_8       1        1          1         1       1
# 137806         AFR_54_1_9       1        1          1         1       1
# 137807         AFR_6_1_10       0        0          0         0       0
# 137808        AFR_97_0_11       1        1          1         1       1
# 137809        AFR_98_1_12       1        1          1         1       1
#
#         saturday  sunday  start_date  end_date
# 0              0       1    20240423  20240523
# 1              0       0    20240423  20240523
# 2              0       0    20240423  20240523
# 3              0       0    20240423  20240523
# 4              0       0    20240423  20240523
# ...          ...     ...         ...       ...
# 137805         1       1    20240423  20240523
# 137806         1       1    20240423  20240523
# 137807         1       1    20240423  20240523
# 137808         1       1    20240423  20240523
# 137809         1       1    20240423  20240523
#
# [137810 rows x 10 columns]

# %%
# filter that only on two taipeis
# Define the patterns
patterns = ["TPE", "NWT", "NTMC", "TRTC"]

# Create a boolean mask with OR conditions for multiple patterns
mask = calendar_df['service_id'].str.startswith(patterns[0])
for pattern in patterns[1:]:
    mask |= calendar_df['service_id'].str.startswith(pattern)

# Filter rows
filtered_calendar_df = calendar_df[mask]

# Show the filtered DataFrame
filtered_calendar_df.to_csv('/home/csl/otp/two_taipei_gtfs/calendar.txt')

filtered_calendar_df
# Out:
#                  service_id  monday  tuesday  wednesday  thursday  friday  \
# 0         TPE101320_0_F_1_1       0        0          0         0       0
# 1         TPE101320_0_F_2_1       1        0          0         0       0
# 2         TPE101320_0_F_3_1       1        0          0         0       0
# 3         TPE101320_0_F_4_1       1        0          0         0       0
# 4         TPE101320_0_F_5_1       1        0          0         0       0
# ...                     ...     ...      ...        ...       ...     ...
# 136347  NTMC_Y_Y-1_1_-1_F_3       1        1          1         1       1
# 136348  NTMC_Y_Y-1_1_-1_F_5       1        1          1         1       1
# 136349  NTMC_Y_Y-1_1_-1_F_6       1        1          1         1       1
# 136350  NTMC_Y_Y-1_0_-1_F_1       0        0          0         0       0
# 136351  NTMC_Y_Y-1_1_-1_F_1       0        0          0         0       0
#
#         saturday  sunday  start_date  end_date
# 0              0       1    20240423  20240523
# 1              0       0    20240423  20240523
# 2              0       0    20240423  20240523
# 3              0       0    20240423  20240523
# 4              0       0    20240423  20240523
# ...          ...     ...         ...       ...
# 136347         0       0    20240423  20240523
# 136348         0       0    20240423  20240523
# 136349         0       0    20240423  20240523
# 136350         1       1    20240423  20240523
# 136351         1       1    20240423  20240523
#
# [78378 rows x 10 columns]
